# %%
import zlib
import numpy as np
import pandas as pd
import sqlite3 as sql
from contextlib import contextmanager


_CMP = '_cmp'


@contextmanager
def open_db_connection(*, file, close=True,
                       lock=None, check_same_thread=False):
    """
    Safety wrapper for the database call.
    """

    if lock is not None:
        lock.acquire()

    con = sql.connect(database=file, check_same_thread=check_same_thread)

    try:
        yield con

    finally:
        if close:
            con.close()
        if lock is not None:
            lock.release()


def get_table_name(file):
    with open_db_connection(file=file, close=True) as con:
        res = pd.read_sql_query(sql="SELECT name FROM sqlite_master WHERE type ='table' AND name NOT LIKE 'sqlite_%'",
                                con=con)
        return res['name'].values


def rename_table(file, tables):
    old_names = get_table_name(file=file)

    with open_db_connection(file=file, close=True) as con:
        cur = con.cursor()
        for old in old_names:
            if old in tables:
                new = tables['old']
                cur.execute(f"ALTER TABLE `{old}` RENAME TO `{new}`")


def get_values_sql(*, file, table='db', columns=None, rows=-1,
                   values_only=False, squeeze_col=True, squeeze_row=True):
    """
    'i_samples' == i_samples_global
    """

    lock = None  # Lock is not necessary fo reading
    if columns is None:
        columns = '*'
    if isinstance(columns, str):
        columns = [columns]
    columns_str = ', '.join(map(str, columns))

    if isinstance(rows, int):
        rows = [rows]
    rows = np.array(rows)

    if rows[0] == -1:  # All samples
        with open_db_connection(file=file, close=True, lock=lock) as con:
            df = pd.read_sql_query(con=con, sql=f"SELECT {columns_str} FROM {table}")  # path_db

    else:
        rows_str = rows + 1  # Attention! Unlike in Python, SQL indices start at 1
        rows_str = ', '.join(map(str, rows_str))
        with open_db_connection(file=file, close=True, lock=lock) as con:
            df = pd.read_sql_query(sql=f"SELECT {columns_str} FROM {table} WHERE ROWID in ({rows_str})",
                                   index_col=rows, con=con)

    value_list = []
    if np.any(columns == ['*']):
        columns = df.columns.values

    if values_only:
        for col in columns:
            value = __decompress_values(value=df.loc[:, col].values, col=col)
            value_list.append(value)

        if len(df) == 1 and squeeze_row:
            for i in range(len(columns)):
                value_list[i] = value_list[i][0]

        if len(value_list) == 1 and squeeze_col:
            value_list = value_list[0]

        return value_list

    # Return pandas.DataFrame
    else:
        for col in columns:
            value = __decompress_values(value=df.loc[:, col].values, col=col)
            df.loc[:, col] = numeric2object_array(value)

        return df


def set_values_sql(*, file, table='db',
                   values, columns, rows=-1, lock=None):
    """
    Note: multidimensional numpy arrays have to be saved as flat to SQL otherwise the order is messed up
    values = ([...], [...], [...], ...)
    """

    # Handle rows argument
    if isinstance(rows, int):
        if rows == -1:
            rows = np.arange(len(values[0])).tolist()
        else:
            rows = [rows]

    rows_sql = (np.array(rows) + 1).tolist()  # Attention! Unlike in Python, SQL indices start at 1

    # Handle columns argument
    if isinstance(columns, str):
        columns = [columns]

    columns_str = '=?, '.join(map(str, columns))
    columns_str += '=?'

    values_rows_sql = change_tuple_order(values + (rows_sql,))
    values_rows_sql = list(values_rows_sql)
    query = f"UPDATE {table} SET {columns_str} WHERE ROWID=?"

    with open_db_connection(file=file, close=True, lock=lock) as con:
        cur = con.cursor()
        if len(values_rows_sql) == 1:
            cur.execute(query, values_rows_sql[0])
        else:
            cur.executemany(query, values_rows_sql)

        con.commit()


def df2sql(df, file, table='db', if_exists='fail', lock=None):
    """
    From DataFrame.to_sql():
        if_exists : {'fail', 'replace', 'append'}, default 'fail'
                   - fail: If table exists, do nothing.
                   - replace: If table exists, drop it, recreate it, and insert Measurements.
                   - append: If table exists, insert Measurements. Create if does not exist.
    """
    with open_db_connection(file=file, close=True, lock=lock) as con:
        df.to_sql(name=table, con=con, if_exists=if_exists, index=False)


# Helper
# Image Compression <-> Decompression
def __decompress_values(value, col):
    # SQL saves everything in binary form -> convert back to numeric, expect the columns which are marked as CMP
    if isinstance(value[0], bytes) and col[-4:] != _CMP:
        if col in ['i_world', 'i_sample', 'n_obstacles']:
            value = np.array([np.frombuffer(v, dtype=int) for v in value], dtype=int)
        elif col in ['rectangle_pos', 'rectangle_position', 'rectangle_size']:
            value = np.array([np.frombuffer(v, dtype=int) for v in value], dtype=object)
        else:
            value = np.array([np.frombuffer(v, dtype=float) for v in value])
        value = np.squeeze(value)

    return value


def change_tuple_order(tpl):
    return tuple(map(lambda *tt: tuple(tt), *tpl))


def numeric2object_array(arr):
    n = arr.shape[0]
    arr_obj = np.zeros(n, dtype=object)
    for i in range(n):
        arr_obj[i] = arr[i]

    return arr_obj


def object2numeric_array(arr):
    s = np.shape(arr)
    arr = np.array([v for v in np.ravel(arr)])
    arr = np.reshape(arr, s + np.shape(arr)[1:])
    return arr


def initialize_array(shape, mode='zeros', dtype=None, order='c'):

    if mode == 'zeros':
        return np.zeros(shape, dtype=dtype, order=order)
    elif mode == 'ones':
        return np.ones(shape, dtype=dtype, order=order)
    elif mode == 'empty':
        return np.empty(shape, dtype=dtype, order=order)
    elif mode == 'random':
        return np.random.random(shape).astype(dtype=dtype, order=order)
    else:
        raise ValueError(f"Unknown initialization method {mode}")


def __dim_voxels(n_voxels, n_dim=None):
    if np.size(n_voxels) == 1:
        try:
            n_voxels = tuple(n_voxels)
        except TypeError:
            n_voxels = (n_voxels,)
        n_voxels *= n_dim
    else:
        n_voxels = tuple(n_voxels)

    return n_voxels


def image_array_shape(n_voxels, n_samples=None, n_dim=None, n_channels=None):
    """
    Helper to set the shape for an image array.
    n_samples=100,  n_voxels=64,          n_dim=2,    n_channels=None  ->  (100, 64, 64)
    n_samples=100,  n_voxels=64,          n_dim=3,    n_channels=2     ->  (100, 64, 64, 64, 2)
    n_samples=None, n_voxel=(10, 11, 12), n_dim=None, n_channels=None  ->  (10, 11, 12)
    """

    shape = __dim_voxels(n_voxels=n_voxels, n_dim=n_dim)

    if n_samples is not None:
        shape = (n_samples,) + shape
    if n_channels is not None:
        shape = shape + (n_channels,)

    return shape


def initialize_image_array(n_voxels, n_dim=None, n_samples=None, n_channels=None,
                           dtype=bool, initialization='zeros'):
    shape = image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_samples=n_samples, n_channels=n_channels)
    return initialize_array(shape=shape, mode=initialization, dtype=dtype)


# Image Compression <-> Decompression
def img2compressed(img, n_dim=-1, level=9):
    """
    Compress the given image with the zlib routine to a binary string.
    Level of compression can be adjusted. A timing with respect to different compression levels for decompression showed
    no difference, so the highest level is default, this corresponds to the largest compression.
    For compression it is slightly slower but this happens just once and not during keras training, so the smaller
    needed memory was favoured.
    Alternative:
    <-> use numpy sparse for the world images, especially in 3d  -> zlib is more effective and more general
    """

    if n_dim == -1:
        return zlib.compress(img.tobytes(), level=level)
    else:
        shape = img.shape[:-n_dim]
        img_cmp = np.empty(shape, dtype=object)
        for idx in np.ndindex(*shape):
            img_cmp[idx] = zlib.compress(img[idx, ...].tobytes(), level=level)
        return img_cmp


def compressed2img(img_cmp, n_voxels, n_dim=None, n_channels=None, dtype=bool):
    """
    Decompress the binary string back to an image of given shape
    """

    shape = np.shape(img_cmp)

    if shape:
        n_samples = np.size(img_cmp)
        img_arr = initialize_image_array(n_voxels=n_voxels, n_dim=n_dim, n_samples=n_samples, n_channels=n_channels,
                                         dtype=dtype)
        for i in range(n_samples):
            img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(
                image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_channels=n_channels))
        return img_arr

    else:
        return np.fromstring(zlib.decompress(img_cmp), dtype=dtype).reshape(
            image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_channels=n_channels))

# %%
import numpy as np
import matplotlib.pyplot as plt



file = './StaticArm04.db'
# TODO change to you own file path

n_voxels = 64
voxel_size = 2.10 / 64     # in m
extent = [-1.05, +1.05, -1.05, +1.05]  # in m
limb_length = 0.25  # m
n_waypoints = 20  # start + 20 inner points + end
n_dim = 2
n_dof = 4
n_worlds = 10000
# n_paths_per_world = 1000

worlds = get_values_sql(file=file, table='worlds')
obstacle_images = compressed2img(img_cmp=worlds.obst_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)

paths = get_values_sql(file=file, table='paths', rows=[0, 1, 2, 1000, 2000])
q_start = object2numeric_array(paths.q_start.values)
q_start = q_start.reshape(-1, 1, n_dof)
q_end= object2numeric_array(paths.q_end.values)
q_end = q_end.reshape(-1, 1, n_dof)
q_paths = object2numeric_array(paths.q_path.values)
q_paths = q_paths.reshape(-1, n_waypoints, n_dof)

#print(q_paths[0])
print(q_start.shape)

# Plot an example
i = 2
#i_world = paths.i_world[i]


def forward_kinematic(q):
    q = np.cumsum(q, axis=-1)
    x = np.concatenate([q[..., np.newaxis], q[..., np.newaxis]], axis=-1)
    x[..., 0] = np.cos(x[..., 0])*limb_length
    x[..., 1] = np.sin(x[..., 1])*limb_length

    shape = np.array(q.shape + (2,))
    shape[-2] = 1
    x = np.concatenate([np.zeros(shape), x], axis=-2)
    x = np.cumsum(x, axis=-2)
    return x

print(obstacle_images.shape)
#print(q_paths)
# Plot an example
fig, ax = plt.subplots()
ax.imshow(obstacle_images[0].T, origin='lower', extent=extent, cmap='binary')
x = forward_kinematic(q_start[i])
ax.plot(*x[0].T, color='k', marker='o', zorder=22)
x = forward_kinematic(q_end[i])
ax.plot(*x[0].T, color='blue', marker='o', zorder=22)
#print(q_paths[i])

x = forward_kinematic(q_paths[i])
ax.plot(*x[0].T, color='black', marker='o', zorder=10)
ax.plot(*x[1].T, color='green', marker='o', zorder=10)
ax.plot(*x[2].T, color='green', marker='o', zorder=10)
ax.plot(*x[3].T, color='green', marker='o', zorder=10)
ax.plot(*x[4].T, color='green', marker='o', zorder=10)
ax.plot(*x[5].T, color='green', marker='o', zorder=10)
ax.plot(*x[6].T, color='green', marker='o', zorder=10)
ax.plot(*x[7].T, color='green', marker='o', zorder=10)
ax.plot(*x[8].T, color='green', marker='o', zorder=10)
ax.plot(*x[9].T, color='green', marker='o', zorder=10)
ax.plot(*x[10].T, color='green', marker='o', zorder=10)
ax.plot(*x[11].T, color='green', marker='o', zorder=10)
ax.plot(*x[12].T, color='green', marker='o', zorder=10)
ax.plot(*x[13].T, color='green', marker='o', zorder=10)
ax.plot(*x[14].T, color='green', marker='o', zorder=10)
ax.plot(*x[15].T, color='green', marker='o', zorder=10)
ax.plot(*x[16].T, color='green', marker='o', zorder=10)
ax.plot(*x[17].T, color='green', marker='o', zorder=10)
ax.plot(*x[18].T, color='green', marker='o', zorder=10)
ax.plot(*x[-1].T, color='red', marker='o', zorder=10)
h = ax.plot(*x[0].T, color='blue', marker='o', zorder=0)[0]
# Out:
# C:\Users\sereen\AppData\Local\Temp/ipykernel_3652/2894094313.py:276: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(
# (5, 1, 4)
# (10000, 64, 64)

# %%
def load_images_for_single_world(world_index, file, paths_per_world=325):
    
    """ Returns an array of tuples where each tuple contains:
        1. Obstacle image of the desired world with different start & end points
        2. Above image plus the path from start to end point
    """
    
    # Initial Parameters
    n_voxels = 64
    voxel_size = 10 / 64     # in m
    extent = [0, 10, 0, 10]  # in m
    n_waypoints = 20  # start + 20 inner points + end
    n_dim = 2
    n_paths_per_world = 1000
    n_worlds = 5000

    worlds = get_values_sql(file=file, table='worlds')
    obstacle_image = compressed2img(img_cmp=worlds.obst_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)[world_index]
    #print(obstacle_image.shape)
    # always 1000 paths belong to one world
    # 0...999     -> world 0
    # 1000...1999 -> world 1
    # 2000...2999 -> world 2
    path_range_start  = world_index * paths_per_world 
    path_range_end = world_index * paths_per_world + paths_per_world 
    n_world_all_paths = [x for x in range(path_range_start, path_range_end)]
    
    paths = get_values_sql(file=file, table='paths', rows=n_world_all_paths)
    
    # Decompressing objects to images
    #path_images = compressed2img(img_cmp=paths.path_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)
   

    q_start = object2numeric_array(paths.q_start.values)
    q_start = q_start.reshape(-1, 1, n_dof)
    q_end= object2numeric_array(paths.q_end.values)
    q_end = q_end.reshape(-1, 1, n_dof)
    q_paths = object2numeric_array(paths.q_path.values)
    q_paths = q_paths.reshape(-1, n_waypoints, n_dof)
    
    path_index= [x for x in range(0,325)]
    #print(obstacle_images.shape)
    #print(q_start.shape)
    input_images = []
    path_coordinates= []
    output_images = []
    #print(obstacle_images[0])
    for i in path_index:
        
        z= np.ones((1,60), dtype=float)
        y= np.ones((1,60), dtype=float)
        new_q_end= np.append(q_end[i],y, axis=1)
        new_q_start= np.append(q_start[i],z, axis=1)
        print(new_q_start.shape)
        print(new_q_end.shape)
        x= np.ones((63,64),dtype=float)
        m = np.ones((63,64),dtype=float)
        new_q_end= np.append(new_q_end,x, axis=0)
        new_q_start= np.append(new_q_start,m, axis=0)
        print(new_q_start.shape)
        print(new_q_end.shape)
        
        input_images.append(np.concatenate((obstacle_image.T[:,:,np.newaxis], new_q_start.T[:,:,np.newaxis], new_q_end.T[:,:,np.newaxis]), axis=-1))
        output_images.append(obstacle_image.T[:,:,np.newaxis])
        
        path_coordinates.append(q_paths[i]) 
       
        
    return input_images, output_images, path_coordinates

# %%
input_images, output_images, path_coordinates = load_images_for_single_world(1, file)
# Reshaping
#input_images = np.reshape(input_images, (-1, 64, 22,3))
input_images = np.reshape(input_images, (-1, 64, 64,3))
print("Input Images Shape after Reshaping: ",input_images.shape)


path_coords = np.reshape(np.array(path_coordinates), (-1, 20, 4))
print("Output Images Shape after Reshaping: ", path_coords.shape)
# Out:
# C:\Users\sereen\AppData\Local\Temp/ipykernel_3652/2894094313.py:276: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# (1, 64)
# (1, 64)
# (64, 64)
# (64, 64)
# Input Images Shape after Reshaping:  (325, 64, 64, 3)
# Output Images Shape after Reshaping:  (325, 20, 4)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
i = 200
ax.imshow((output_images[i]).astype(np.uint8), origin='lower', extent=extent, cmap='binary')



x = forward_kinematic(path_coordinates[i])
ax.plot(*x[0].T, color='black', marker='o', zorder=10)
ax.plot(*x[1].T, color='green', marker='o', zorder=10)
ax.plot(*x[2].T, color='green', marker='o', zorder=10)
ax.plot(*x[3].T, color='green', marker='o', zorder=10)
ax.plot(*x[4].T, color='green', marker='o', zorder=10)
ax.plot(*x[5].T, color='green', marker='o', zorder=10)
ax.plot(*x[6].T, color='green', marker='o', zorder=10)
ax.plot(*x[7].T, color='green', marker='o', zorder=10)
ax.plot(*x[8].T, color='green', marker='o', zorder=10)
ax.plot(*x[9].T, color='green', marker='o', zorder=10)
ax.plot(*x[10].T, color='green', marker='o', zorder=10)
ax.plot(*x[11].T, color='green', marker='o', zorder=10)
ax.plot(*x[12].T, color='green', marker='o', zorder=10)
ax.plot(*x[13].T, color='green', marker='o', zorder=10)
ax.plot(*x[14].T, color='green', marker='o', zorder=10)
ax.plot(*x[15].T, color='green', marker='o', zorder=10)
ax.plot(*x[16].T, color='green', marker='o', zorder=10)
ax.plot(*x[17].T, color='green', marker='o', zorder=10)
ax.plot(*x[18].T, color='green', marker='o', zorder=10)
ax.plot(*x[-1].T, color='red', marker='o', zorder=10)
h = ax.plot(*x[0].T, color='blue', marker='o', zorder=0)[0]

# %%
from sklearn.model_selection import train_test_split
features_train, features_test, obst_train,obst_test, labels_train, labels_test = train_test_split(input_images, output_images, path_coords, test_size= 0.2, random_state=42)
print(features_test.shape)
print(features_train.shape)
# Out:
# (65, 64, 64, 3)
# (260, 64, 64, 3)

# %%
import os
import numpy as np
import cv2
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.client import device_lib
import datetime
import matplotlib.pyplot as plt

# %%
image_width = 64
image_height = 64
channels = 3

# %%
input_layer= tf.keras.layers.Input((image_width, image_height, channels))
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(input_layer)
print(input_layer.shape)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.1)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)

c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), padding='same', strides=(2, 2))(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.1)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), padding='same', strides=(2, 2))(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.1)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), padding='same', strides=(2, 2))(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), padding='same', strides=(2, 2))(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
#print(c9.shape)


output_layer = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

flat = tf.keras.layers.Flatten()(output_layer)

d3 = tf.keras.layers.Dense(80)(flat)
    
coordinates_output = tf.keras.layers.Reshape((20,4))(d3)


print(coordinates_output.shape)
# Out:
# (None, 64, 64, 3)
# (None, 20, 4)

# %%
model = tf.keras.Model(inputs=input_layer, outputs=coordinates_output)
log_dir = "C:/Robot_motion_planing/adlr_team_11/Anshasi/log/"

model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mean_absolute_error', metrics=['mean_squared_error'])
history = model.fit(features_train, labels_train, epochs=100)
model.summary()
print("------------Building the Model finished------------------")
model.save('C:/Robot_motion_planing/adlr_team_11/Anshasi/Arm_1_world-100-epochs')
# Out:
# Epoch 1/100
# 9/9 [==============================] - 5s 257ms/step - loss: 1.3081 - mean_squared_error: 2.4534
# Epoch 2/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2880 - mean_squared_error: 2.4055
# Epoch 3/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2690 - mean_squared_error: 2.3304
# Epoch 4/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2743 - mean_squared_error: 2.3864
# Epoch 5/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2727 - mean_squared_error: 2.3423
# Epoch 6/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.2732 - mean_squared_error: 2.3349
# Epoch 7/100
# 9/9 [==============================] - 2s 268ms/step - loss: 1.2658 - mean_squared_error: 2.3327
# Epoch 8/100
# 9/9 [==============================] - 2s 257ms/step - loss: 1.2644 - mean_squared_error: 2.3360
# Epoch 9/100
# 9/9 [==============================] - 2s 260ms/step - loss: 1.2646 - mean_squared_error: 2.3360
# Epoch 10/100
# 9/9 [==============================] - 2s 257ms/step - loss: 1.2640 - mean_squared_error: 2.3362
# Epoch 11/100
# 9/9 [==============================] - 2s 265ms/step - loss: 1.2632 - mean_squared_error: 2.3353
# Epoch 12/100
# 9/9 [==============================] - 3s 280ms/step - loss: 1.2626 - mean_squared_error: 2.3334
# Epoch 13/100
# 9/9 [==============================] - 3s 276ms/step - loss: 1.2637 - mean_squared_error: 2.3328
# Epoch 14/100
# 9/9 [==============================] - 3s 281ms/step - loss: 1.2627 - mean_squared_error: 2.3271
# Epoch 15/100
# 9/9 [==============================] - 3s 293ms/step - loss: 1.2629 - mean_squared_error: 2.3272
# Epoch 16/100
# 9/9 [==============================] - 2s 271ms/step - loss: 1.2732 - mean_squared_error: 2.3272
# Epoch 17/100
# 9/9 [==============================] - 3s 279ms/step - loss: 1.2744 - mean_squared_error: 2.3281
# Epoch 18/100
# 9/9 [==============================] - 2s 258ms/step - loss: 1.2872 - mean_squared_error: 2.3479
# Epoch 19/100
# 9/9 [==============================] - 2s 254ms/step - loss: 1.2886 - mean_squared_error: 2.3481
# Epoch 20/100
# 9/9 [==============================] - 2s 250ms/step - loss: 1.2876 - mean_squared_error: 2.3464
# Epoch 21/100
# 9/9 [==============================] - 2s 249ms/step - loss: 1.2867 - mean_squared_error: 2.3449
# Epoch 22/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2857 - mean_squared_error: 2.3429
# Epoch 23/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2847 - mean_squared_error: 2.3415
# Epoch 24/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2840 - mean_squared_error: 2.3403
# Epoch 25/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2831 - mean_squared_error: 2.3386
# Epoch 26/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2826 - mean_squared_error: 2.3381
# Epoch 27/100
# 9/9 [==============================] - 2s 251ms/step - loss: 1.2816 - mean_squared_error: 2.3361
# Epoch 28/100
# 9/9 [==============================] - 2s 253ms/step - loss: 1.2807 - mean_squared_error: 2.3347
# Epoch 29/100
# 9/9 [==============================] - 2s 249ms/step - loss: 1.2802 - mean_squared_error: 2.3342
# Epoch 30/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2795 - mean_squared_error: 2.3327
# Epoch 31/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2789 - mean_squared_error: 2.3317
# Epoch 32/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2782 - mean_squared_error: 2.3307
# Epoch 33/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2776 - mean_squared_error: 2.3297
# Epoch 34/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2770 - mean_squared_error: 2.3289
# Epoch 35/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2764 - mean_squared_error: 2.3280
# Epoch 36/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2761 - mean_squared_error: 2.3279
# Epoch 37/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2755 - mean_squared_error: 2.3273
# Epoch 38/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2750 - mean_squared_error: 2.3264
# Epoch 39/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2742 - mean_squared_error: 2.3249
# Epoch 40/100
# 9/9 [==============================] - 2s 260ms/step - loss: 1.2739 - mean_squared_error: 2.3248
# Epoch 41/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.2734 - mean_squared_error: 2.3246
# Epoch 42/100
# 9/9 [==============================] - 2s 257ms/step - loss: 1.2733 - mean_squared_error: 2.3245
# Epoch 43/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2725 - mean_squared_error: 2.3230
# Epoch 44/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2720 - mean_squared_error: 2.3220
# Epoch 45/100
# 9/9 [==============================] - 2s 252ms/step - loss: 1.2719 - mean_squared_error: 2.3225
# Epoch 46/100
# 9/9 [==============================] - 2s 251ms/step - loss: 1.2715 - mean_squared_error: 2.3223
# Epoch 47/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2712 - mean_squared_error: 2.3219
# Epoch 48/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2706 - mean_squared_error: 2.3212
# Epoch 49/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2703 - mean_squared_error: 2.3209
# Epoch 50/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2702 - mean_squared_error: 2.3208
# Epoch 51/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2697 - mean_squared_error: 2.3207
# Epoch 52/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2645 - mean_squared_error: 2.3178
# Epoch 53/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2628 - mean_squared_error: 2.3273
# Epoch 54/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2644 - mean_squared_error: 2.3273
# Epoch 55/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2695 - mean_squared_error: 2.3201
# Epoch 56/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2691 - mean_squared_error: 2.3197
# Epoch 57/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2689 - mean_squared_error: 2.3196
# Epoch 58/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2686 - mean_squared_error: 2.3194
# Epoch 59/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2684 - mean_squared_error: 2.3194
# Epoch 60/100
# 9/9 [==============================] - 2s 251ms/step - loss: 1.2680 - mean_squared_error: 2.3190
# Epoch 61/100
# 9/9 [==============================] - 2s 243ms/step - loss: 1.2678 - mean_squared_error: 2.3191
# Epoch 62/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2675 - mean_squared_error: 2.3188
# Epoch 63/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2673 - mean_squared_error: 2.3188
# Epoch 64/100
# 9/9 [==============================] - 2s 243ms/step - loss: 1.2671 - mean_squared_error: 2.3188
# Epoch 65/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2669 - mean_squared_error: 2.3185
# Epoch 66/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2667 - mean_squared_error: 2.3186
# Epoch 67/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2665 - mean_squared_error: 2.3184
# Epoch 68/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2664 - mean_squared_error: 2.3189
# Epoch 69/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2661 - mean_squared_error: 2.3183
# Epoch 70/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2659 - mean_squared_error: 2.3181
# Epoch 71/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2657 - mean_squared_error: 2.3181
# Epoch 72/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2656 - mean_squared_error: 2.3179
# Epoch 73/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2655 - mean_squared_error: 2.3182
# Epoch 74/100
# 9/9 [==============================] - 2s 243ms/step - loss: 1.2653 - mean_squared_error: 2.3181
# Epoch 75/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2653 - mean_squared_error: 2.3189
# Epoch 76/100
# 9/9 [==============================] - 2s 250ms/step - loss: 1.2651 - mean_squared_error: 2.3185
# Epoch 77/100
# 9/9 [==============================] - 2s 243ms/step - loss: 1.2648 - mean_squared_error: 2.3181
# Epoch 78/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2647 - mean_squared_error: 2.3179
# Epoch 79/100
# 9/9 [==============================] - 2s 247ms/step - loss: 1.2646 - mean_squared_error: 2.3180
# Epoch 80/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2644 - mean_squared_error: 2.3183
# Epoch 81/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2643 - mean_squared_error: 2.3184
# Epoch 82/100
# 9/9 [==============================] - 2s 243ms/step - loss: 1.2642 - mean_squared_error: 2.3183
# Epoch 83/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2641 - mean_squared_error: 2.3184
# Epoch 84/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2639 - mean_squared_error: 2.3185
# Epoch 85/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2638 - mean_squared_error: 2.3185
# Epoch 86/100
# 9/9 [==============================] - 2s 244ms/step - loss: 1.2637 - mean_squared_error: 2.3187
# Epoch 87/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2636 - mean_squared_error: 2.3187
# Epoch 88/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2634 - mean_squared_error: 2.3185
# Epoch 89/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.2634 - mean_squared_error: 2.3188
# Epoch 90/100
# 9/9 [==============================] - 2s 249ms/step - loss: 1.2633 - mean_squared_error: 2.3189
# Epoch 91/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2632 - mean_squared_error: 2.3191
# Epoch 92/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2630 - mean_squared_error: 2.3189
# Epoch 93/100
# 9/9 [==============================] - 2s 250ms/step - loss: 1.2630 - mean_squared_error: 2.3193
# Epoch 94/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2630 - mean_squared_error: 2.3195
# Epoch 95/100
# 9/9 [==============================] - 2s 250ms/step - loss: 1.2631 - mean_squared_error: 2.3200
# Epoch 96/100
# 9/9 [==============================] - 2s 249ms/step - loss: 1.2630 - mean_squared_error: 2.3197
# Epoch 97/100
# 9/9 [==============================] - 2s 246ms/step - loss: 1.2628 - mean_squared_error: 2.3196
# Epoch 98/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2628 - mean_squared_error: 2.3200
# Epoch 99/100
# 9/9 [==============================] - 2s 248ms/step - loss: 1.2630 - mean_squared_error: 2.3206
# Epoch 100/100
# 9/9 [==============================] - 2s 245ms/step - loss: 1.2629 - mean_squared_error: 2.3206
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 16)   0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 16)   2320        dropout_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 32, 32, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 32)   9248        dropout_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 64)   18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 16, 16, 64)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   36928       dropout_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 8, 8, 128)    0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    147584      dropout_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 4, 4, 128)    0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 256)    295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 4, 4, 256)    0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 256)    590080      dropout_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 8, 8, 128)    131200      conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8, 8, 256)    0           conv2d_transpose_8[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    295040      concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 8, 8, 128)    0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 128)    147584      dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 16, 16, 64)   32832       conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 64)   73792       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 16, 16, 64)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 64)   36928       dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_10[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32, 32, 32)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 32)   9248        dropout_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 64, 64, 16)   0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 16)   2320        dropout_26[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 1)    17          conv2d_55[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4096)         0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           327760      flatten_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 20, 4)        0           dense_2[0][0]
# ==================================================================================================
# Total params: 2,268,865
# Trainable params: 2,268,865
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ------------Building the Model finished------------------
# INFO:tensorflow:Assets written to: C:/Robot_motion_planing/adlr_team_11/Anshasi/Arm_1_world-100-epochs\assets

# %%
#model = keras.models.load_model('C:/Robot_motion_planing/adlr_team_11/Anshasi/Arm_1_world')

# %%
loss_train = history.history['loss']
#loss_val = history.history['mean_squared_error']
ephocs= range(0,40)
plt.plot(ephocs,loss_train, 'g', label= 'training loss')
#plt.plot(ephocs,loss_train, 'b', label= 'testing loss')
plt.title( 'Training loss 1 worlds Arm dataset')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss_1_world_Arm.jpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6584/4239039119.py in <module>
# ----> 1 loss_train = history.history['loss']
#       2 #loss_val = history.history['mean_squared_error']
#       3 ephocs= range(0,40)
#       4 plt.plot(ephocs,loss_train, 'g', label= 'training loss')
#       5 #plt.plot(ephocs,loss_train, 'b', label= 'testing loss')
#
# NameError: name 'history' is not defined

# %%
features_test = np.reshape(np.array(features_test), (-1,64, 64,3))
print("Output Images Shape after Reshaping: ", features_test.shape)
# Out:
# Output Images Shape after Reshaping:  (65, 64, 64, 3)

# %%
predectid = model.predict(features_test)

# %%
features_test = np.reshape(features_test, (-1, 64, 64))
obst_test= np.reshape(obst_test, (-1,64,64))
print("Input Images Shape after Reshaping: ",features_test.shape)
i=16
fig, ax = plt.subplots(1,2, figsize=(13,13))

ax[0].imshow(obst_test[i], origin='lower', extent=extent, cmap='binary')


x = forward_kinematic(labels_test[i])
ax[0].plot(*x[0].T, color='black', marker='o', zorder=11)
ax[0].plot(*x[1].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[2].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[3].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[4].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[5].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[6].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[7].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[8].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[9].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[10].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[11].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[12].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[13].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[14].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[15].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[16].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[17].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[18].T, color='green', marker='o', zorder=10)
ax[0].plot(*x[-1].T, color='red', marker='o', zorder=11)
h = ax[0].plot(*x[0].T, color='blue', marker='o', zorder=0)[0]
ax[0].set_title('Ground Truth')
ax[1].imshow(obst_test[i], origin='lower', extent=extent, cmap='binary')
x = forward_kinematic(predectid[i])
ax[1].plot(*x[0].T, color='black', marker='o', zorder=11)
ax[1].plot(*x[1].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[2].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[3].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[4].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[5].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[6].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[7].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[8].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[9].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[10].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[11].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[12].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[13].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[14].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[15].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[16].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[17].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[18].T, color='green', marker='o', zorder=10)
ax[1].plot(*x[-1].T, color='red', marker='o', zorder=11)
h = ax[1].plot(*x[0].T, color='blue', marker='o', zorder=0)[0]
ax[1].set_title('Prediction')
plt.savefig('16.jpg')
# Out:
# Input Images Shape after Reshaping:  (195, 64, 64)
