# %% [markdown]
# ### Utility Functions

# %%
import tensorflow as tf
from IPython.display import clear_output
# Out:
# 2021-12-08 09:15:23.938604: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-08 09:15:23.938661: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import zlib
import numpy as np
import pandas as pd
import sqlite3 as sql
from contextlib import contextmanager


_CMP = '_cmp'


@contextmanager
def open_db_connection(*, file, close=True,
                       lock=None, check_same_thread=False):
    """
    Safety wrapper for the database call.
    """

    if lock is not None:
        lock.acquire()

    con = sql.connect(database=file, check_same_thread=check_same_thread)

    try:
        yield con

    finally:
        if close:
            con.close()
        if lock is not None:
            lock.release()


def get_table_name(file):
    with open_db_connection(file=file, close=True) as con:
        res = pd.read_sql_query(sql="SELECT name FROM sqlite_master WHERE type ='table' AND name NOT LIKE 'sqlite_%'",
                                con=con)
        return res['name'].values


def rename_table(file, tables):
    old_names = get_table_name(file=file)

    with open_db_connection(file=file, close=True) as con:
        cur = con.cursor()
        for old in old_names:
            if old in tables:
                new = tables['old']
                cur.execute(f"ALTER TABLE `{old}` RENAME TO `{new}`")


def get_values_sql(*, file, table='db', columns=None, rows=-1,
                   values_only=False, squeeze_col=True, squeeze_row=True):
    """
    'i_samples' == i_samples_global
    """

    lock = None  # Lock is not necessary fo reading
    if columns is None:
        columns = '*'
    if isinstance(columns, str):
        columns = [columns]
    columns_str = ', '.join(map(str, columns))

    if isinstance(rows, int):
        rows = [rows]
    rows = np.array(rows)

    if rows[0] == -1:  # All samples
        with open_db_connection(file=file, close=True, lock=lock) as con:
            df = pd.read_sql_query(con=con, sql=f"SELECT {columns_str} FROM {table}")  # path_db

    else:
        rows_str = rows + 1  # Attention! Unlike in Python, SQL indices start at 1
        rows_str = ', '.join(map(str, rows_str))
        with open_db_connection(file=file, close=True, lock=lock) as con:
            df = pd.read_sql_query(sql=f"SELECT {columns_str} FROM {table} WHERE ROWID in ({rows_str})",
                                   index_col=rows, con=con)

    value_list = []
    if np.any(columns == ['*']):
        columns = df.columns.values

    if values_only:
        for col in columns:
            value = __decompress_values(value=df.loc[:, col].values, col=col)
            value_list.append(value)

        if len(df) == 1 and squeeze_row:
            for i in range(len(columns)):
                value_list[i] = value_list[i][0]

        if len(value_list) == 1 and squeeze_col:
            value_list = value_list[0]

        return value_list

    # Return pandas.DataFrame
    else:
        for col in columns:
            value = __decompress_values(value=df.loc[:, col].values, col=col)
            df.loc[:, col] = numeric2object_array(value)

        return df


def set_values_sql(*, file, table='db',
                   values, columns, rows=-1, lock=None):
    """
    Note: multidimensional numpy arrays have to be saved as flat to SQL otherwise the order is messed up
    values = ([...], [...], [...], ...)
    """

    # Handle rows argument
    if isinstance(rows, int):
        if rows == -1:
            rows = np.arange(len(values[0])).tolist()
        else:
            rows = [rows]

    rows_sql = (np.array(rows) + 1).tolist()  # Attention! Unlike in Python, SQL indices start at 1

    # Handle columns argument
    if isinstance(columns, str):
        columns = [columns]

    columns_str = '=?, '.join(map(str, columns))
    columns_str += '=?'

    values_rows_sql = change_tuple_order(values + (rows_sql,))
    values_rows_sql = list(values_rows_sql)
    query = f"UPDATE {table} SET {columns_str} WHERE ROWID=?"

    with open_db_connection(file=file, close=True, lock=lock) as con:
        cur = con.cursor()
        if len(values_rows_sql) == 1:
            cur.execute(query, values_rows_sql[0])
        else:
            cur.executemany(query, values_rows_sql)

        con.commit()


def df2sql(df, file, table='db', if_exists='fail', lock=None):
    """
    From DataFrame.to_sql():
        if_exists : {'fail', 'replace', 'append'}, default 'fail'
                   - fail: If table exists, do nothing.
                   - replace: If table exists, drop it, recreate it, and insert Measurements.
                   - append: If table exists, insert Measurements. Create if does not exist.
    """
    with open_db_connection(file=file, close=True, lock=lock) as con:
        df.to_sql(name=table, con=con, if_exists=if_exists, index=False)


# Helper
# Image Compression <-> Decompression
def __decompress_values(value, col):
    # SQL saves everything in binary form -> convert back to numeric, expect the columns which are marked as CMP
    if isinstance(value[0], bytes) and col[-4:] != _CMP:
        if col in ['i_world', 'i_sample', 'n_obstacles']:
            value = np.array([np.frombuffer(v, dtype=int) for v in value], dtype=int)
        elif col in ['rectangle_pos', 'rectangle_position', 'rectangle_size']:
            value = np.array([np.frombuffer(v, dtype=int) for v in value], dtype=object)
        else:
            value = np.array([np.frombuffer(v, dtype=float) for v in value])
        value = np.squeeze(value)

    return value


def change_tuple_order(tpl):
    return tuple(map(lambda *tt: tuple(tt), *tpl))


def numeric2object_array(arr):
    n = arr.shape[0]
    arr_obj = np.zeros(n, dtype=object)
    for i in range(n):
        arr_obj[i] = arr[i]

    return arr_obj


def object2numeric_array(arr):
    s = np.shape(arr)
    arr = np.array([v for v in np.ravel(arr)])
    arr = np.reshape(arr, s + np.shape(arr)[1:])
    return arr


def initialize_array(shape, mode='zeros', dtype=None, order='c'):

    if mode == 'zeros':
        return np.zeros(shape, dtype=dtype, order=order)
    elif mode == 'ones':
        return np.ones(shape, dtype=dtype, order=order)
    elif mode == 'empty':
        return np.empty(shape, dtype=dtype, order=order)
    elif mode == 'random':
        return np.random.random(shape).astype(dtype=dtype, order=order)
    else:
        raise ValueError(f"Unknown initialization method {mode}")


def __dim_voxels(n_voxels, n_dim=None):
    if np.size(n_voxels) == 1:
        try:
            n_voxels = tuple(n_voxels)
        except TypeError:
            n_voxels = (n_voxels,)
        n_voxels *= n_dim
    else:
        n_voxels = tuple(n_voxels)

    return n_voxels


def image_array_shape(n_voxels, n_samples=None, n_dim=None, n_channels=None):
    """
    Helper to set the shape for an image array.
    n_samples=100,  n_voxels=64,          n_dim=2,    n_channels=None  ->  (100, 64, 64)
    n_samples=100,  n_voxels=64,          n_dim=3,    n_channels=2     ->  (100, 64, 64, 64, 2)
    n_samples=None, n_voxel=(10, 11, 12), n_dim=None, n_channels=None  ->  (10, 11, 12)
    """

    shape = __dim_voxels(n_voxels=n_voxels, n_dim=n_dim)

    if n_samples is not None:
        shape = (n_samples,) + shape
    if n_channels is not None:
        shape = shape + (n_channels,)

    return shape


def initialize_image_array(n_voxels, n_dim=None, n_samples=None, n_channels=None,
                           dtype=bool, initialization='zeros'):
    shape = image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_samples=n_samples, n_channels=n_channels)
    return initialize_array(shape=shape, mode=initialization, dtype=dtype)


# Image Compression <-> Decompression
def img2compressed(img, n_dim=-1, level=9):
    """
    Compress the given image with the zlib routine to a binary string.
    Level of compression can be adjusted. A timing with respect to different compression levels for decompression showed
    no difference, so the highest level is default, this corresponds to the largest compression.
    For compression it is slightly slower but this happens just once and not during keras training, so the smaller
    needed memory was favoured.
    Alternative:
    <-> use numpy sparse for the world images, especially in 3d  -> zlib is more effective and more general
    """

    if n_dim == -1:
        return zlib.compress(img.tobytes(), level=level)
    else:
        shape = img.shape[:-n_dim]
        img_cmp = np.empty(shape, dtype=object)
        for idx in np.ndindex(*shape):
            img_cmp[idx] = zlib.compress(img[idx, ...].tobytes(), level=level)
        return img_cmp


def compressed2img(img_cmp, n_voxels, n_dim=None, n_channels=None, dtype=bool):
    """
    Decompress the binary string back to an image of given shape
    """

    shape = np.shape(img_cmp)

    if shape:
        n_samples = np.size(img_cmp)
        img_arr = initialize_image_array(n_voxels=n_voxels, n_dim=n_dim, n_samples=n_samples, n_channels=n_channels,
                                         dtype=dtype)
        for i in range(n_samples):
            img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(
                image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_channels=n_channels))
        return img_arr

    else:
        return np.fromstring(zlib.decompress(img_cmp), dtype=dtype).reshape(
            image_array_shape(n_voxels=n_voxels, n_dim=n_dim, n_channels=n_channels))

# %% [markdown]
# ### Main

# %%
import numpy as np

file = '../SingleSphere02.db'
# TODO change to you own directory


n_voxels = 64
voxel_size = 10 / 64     # in m
extent = [0, 10, 0, 10]  # in m
n_waypoints = 22  # start + 20 inner points + end
n_dim = 2
n_paths_per_world = 1000
n_worlds = 5000


worlds = get_values_sql(file=file, table='worlds')
obstacle_images = compressed2img(img_cmp=worlds.obst_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)

# always 1000 paths belong to one world
# 0...999     -> world 0
# 1000...1999 -> world 1
# 2000...2999 -> world 2
paths = get_values_sql(file=file, table='paths', rows=[0, 1, 2, 1000, 2000])
path_images = compressed2img(img_cmp=paths.path_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)
start_images = compressed2img(img_cmp=paths.start_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)
end_images = compressed2img(img_cmp=paths.end_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)

q_paths = object2numeric_array(paths.q_path.values)
q_paths = q_paths.reshape(-1, n_waypoints, n_dim)

# Plot an example
i = 0
i_world = paths.i_world[i]

import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.imshow(obstacle_images[i_world].T, origin='lower', extent=extent, cmap='binary',)
ax.imshow(start_images[i].T, origin='lower', extent=extent, cmap='Greens', alpha=0.4)
ax.imshow(end_images[i].T, origin='lower', extent=extent, cmap='Reds', alpha=0.4)
ax.imshow(path_images[i].T, origin='lower', extent=extent, cmap='Blues', alpha=0.2)
ax.axis('off')
ax.plot(*q_paths[i].T, color='k', marker='o')
plt.show()
# Out:
# /tmp/ipykernel_34/1467519210.py:276: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(

# %% [markdown]
# # Creating Image datasets

# %%
def load_images_for_single_world(world_index, file='../SingleSphere02.db', paths_per_world=1000):
    
    """ Returns an array of tuples where each tuple contains:
        1. Obstacle image of the desired world with different start & end points
        2. Above image plus the path from start to end point
    """
    
    # Initial Parameters
    n_voxels = 64
    voxel_size = 10 / 64     # in m
    extent = [0, 10, 0, 10]  # in m
    n_waypoints = 22  # start + 20 inner points + end
    n_dim = 2
    n_paths_per_world = 1000
    n_worlds = 5000

    worlds = get_values_sql(file=file, table='worlds')
    obstacle_image = compressed2img(img_cmp=worlds.obst_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)[world_index]
    
    # always 1000 paths belong to one world
    # 0...999     -> world 0
    # 1000...1999 -> world 1
    # 2000...2999 -> world 2
    path_range_start  = world_index * paths_per_world
    path_range_end = world_index * paths_per_world + paths_per_world
    n_world_all_paths = [x for x in range(path_range_start, path_range_end)]
    
    paths = get_values_sql(file=file, table='paths', rows=n_world_all_paths)
    
    # Decompressing objects to images
    path_images = compressed2img(img_cmp=paths.path_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)
    start_images = compressed2img(img_cmp=paths.start_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)
    end_images = compressed2img(img_cmp=paths.end_img_cmp.values, n_voxels=n_voxels, n_dim=n_dim)

    input_images = []
    output_images = []
    for i in n_world_all_paths:
        input_images.append(obstacle_images[i_world].T + start_images[i].T + end_images[i].T)
        output_images.append(path_images[i].T)
    return input_images, output_images

# %%
input_images, output_images = load_images_for_single_world(0)
# Out:
# /tmp/ipykernel_34/1467519210.py:276: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img_arr[i, ...] = np.fromstring(zlib.decompress(img_cmp[i]), dtype=dtype).reshape(

# %%
# Display Images
def plot_image(image_array):
    ''' Displays numpy arrays'''
    fig, ax = plt.subplots()
    ax.imshow(image_array, origin='lower', extent=extent, cmap='binary',)
    plt.show()

# %% [markdown]
# # Testing

# %%
# Expanding dimension (64,64) -> (64,64,1)
X = [np.expand_dims(i, axis=2) for i in input_images]
y = [np.expand_dims(i, axis=2) for i in output_images]

# Splitting into test and train
X_train = np.array(X[800:])
X_test = np.array(X[:800])
y_train = np.array(y[800:])
y_test = np.array(y[:800])

# %%
input_shape = (64,64,1)

def gen_model():
    model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    #tf.keras.layers.Flatten(activation='relu')
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(64*64, activation='relu'),
    tf.keras.layers.Reshape((64, 64))
        
     ])

    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.mean_squared_error,
                  metrics=[tf.keras.metrics.RootMeanSquaredError()])

    return model

# %%
model = gen_model()

# %%
EPOCHS = 200
model.fit(X_train, y_train, epochs=EPOCHS, steps_per_epoch=10)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 2/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 3/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 4/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 5/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 6/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 7/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 8/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 9/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 10/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 11/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 12/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 13/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 14/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 15/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 16/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 17/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 18/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 19/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 20/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 21/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 22/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 23/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 24/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 25/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 26/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 27/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 28/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 29/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 30/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 31/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198
# Epoch 32/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 33/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 34/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 35/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 36/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209
# Epoch 37/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215
# Epoch 38/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222
# Epoch 39/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232
# Epoch 40/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0153 - root_mean_squared_error: 0.1239
# Epoch 41/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232
# Epoch 42/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233
# Epoch 43/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230
# Epoch 44/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229
# Epoch 45/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221
# Epoch 46/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216
# Epoch 47/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214
# Epoch 48/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214
# Epoch 49/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217
# Epoch 50/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218
# Epoch 51/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215
# Epoch 52/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214
# Epoch 53/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209
# Epoch 54/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 55/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202
# Epoch 56/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 57/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 58/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 59/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 60/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 61/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 62/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 63/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0142 - root_mean_squared_error: 0.1194
# Epoch 64/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 65/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 66/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 67/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191
# Epoch 68/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191
# Epoch 69/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 70/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189
# Epoch 71/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 72/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 73/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 74/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 75/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 76/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 77/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 78/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 79/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 80/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 81/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 82/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 83/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 84/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 85/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 86/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 87/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 88/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 89/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 90/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 91/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 92/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 93/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 94/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 95/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 96/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 97/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191
# Epoch 98/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 99/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 100/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 101/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 102/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 103/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 104/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 105/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202
# Epoch 106/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 107/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 108/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 109/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198
# Epoch 110/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 111/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 112/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 113/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 114/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 115/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 116/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 117/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 118/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 119/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 120/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207
# Epoch 121/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208
# Epoch 122/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210
# Epoch 123/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209
# Epoch 124/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202
# Epoch 125/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 126/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 127/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 128/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 129/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 130/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 131/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 132/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 133/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 134/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202
# Epoch 135/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 136/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 137/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 138/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 139/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 140/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207
# Epoch 141/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208
# Epoch 142/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 143/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 144/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 145/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 146/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 147/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194
# Epoch 148/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 149/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 150/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 151/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 152/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 153/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 154/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185
# Epoch 155/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 156/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 157/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 158/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 159/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 160/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 162/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 163/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 164/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 165/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189
# Epoch 166/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 168/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 169/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197
# Epoch 170/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202
# Epoch 171/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 172/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 173/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 174/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 175/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198
# Epoch 176/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198
# Epoch 177/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 178/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196
# Epoch 179/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 180/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202
# Epoch 181/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 182/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 183/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207
# Epoch 184/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 185/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212
# Epoch 186/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215
# Epoch 187/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212
# Epoch 188/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 189/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 190/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 191/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 192/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204
# Epoch 193/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 194/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 195/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 196/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 197/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 198/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187
# Epoch 199/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 200/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_39 (Flatten)        (None, 4096)              0
#
#  dense_125 (Dense)           (None, 128)               524416
#
#  dense_126 (Dense)           (None, 64)                8256
#
#  dense_127 (Dense)           (None, 32)                2080
#
#  dense_128 (Dense)           (None, 4096)              135168
#
#  reshape_29 (Reshape)        (None, 64, 64)            0
#
# =================================================================
# Total params: 669,920
# Trainable params: 669,920
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(X_test)

# %%
print("Predicted Path Image")
plot_image(y_pred[3])
# Out:
# Predicted Path Image

# %%
print("Real Path Image")
plot_image(y_test[3])
# Out:
# Real Path Image

# %% [markdown]
# # ---------------------------------------------------
